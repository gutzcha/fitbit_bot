# %%
import os
from langchain.chat_models import init_chat_model

# %%
model_id = "ollama:gemma3:270m"
model = init_chat_model(model=model_id, temprature=0)

# %%
model.invoke("hello")
# Out:
# AIMessage(content='Hello! How can I help you today?\n', additional_kwargs={}, response_metadata={'model': 'gemma3:270m', 'created_at': '2026-01-29T14:37:09.1506779Z', 'done': True, 'done_reason': 'stop', 'total_duration': 10148950500, 'load_duration': 9842103300, 'prompt_eval_count': 10, 'prompt_eval_duration': 57782000, 'eval_count': 11, 'eval_duration': 222454300, 'logprobs': None, 'model_name': 'gemma3:270m', 'model_provider': 'ollama'}, id='lc_run--019c0a2f-9ef5-79c3-8cc7-c827f5bb1b24-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 11, 'total_tokens': 21})

# %%
embedding_model = "mxbai-embed-large:335m"
